# %% [markdown]
# # 01. 다양한 단어의 표현 방법

# %% [markdown]
# 1. 단어의 표현 방법
#
# *   국소 표현(Local Representation)
#
#      : 해당 단어 자체만 보고 특정값 매핑하여 단어 표현
# *   분산 표현(Distributed Representation)
#
#      : 단어를 표현하기 위해 주변을 참고 -> 뉘앙스 표현 가능

# %% [markdown]
# 2. 단어 표현의 카테고리화
#
# ![image.png](data:image/png;base64,...)
